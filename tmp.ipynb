# %%
from datasets import load_dataset
from datasets import DatasetDict

# load HuggingFaceM4/A-OKVQA@train and make a new dataset with only 10 rows
dataset = load_dataset("HuggingFaceM4/A-OKVQA")
dataset = dataset["train"].select(range(32))
dataset = DatasetDict({"train": dataset})
print(dataset)
# push 
dataset.push_to_hub("Amasia-MLLM/A-OKVQA")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'question_id', 'question', 'choices', 'correct_choice_idx', 'direct_answers', 'difficult_direct_answer', 'rationales'],
#         num_rows: 10
#     })
# })
# Map: 100%|██████████| 10/10 [00:00<00:00, 1595.58 examples/s]?it/s]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 432.40ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Amasia-MLLM/A-OKVQA/commit/40778b360b5738f8bde783617d46da3929d71947', commit_message='Upload dataset', commit_description='', oid='40778b360b5738f8bde783617d46da3929d71947', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Amasia-MLLM/A-OKVQA', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Amasia-MLLM/A-OKVQA'), pr_revision=None, pr_num=None)
